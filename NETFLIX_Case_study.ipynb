# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("original_netflix.csv")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.size
# Out:
# 105684

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# apply duplicated for check if there any duplicate value present in the dataset if any duplicate value present in data set then we have to drop the duplicate row data.

# %%
data.isna()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# To check in which column how much null value are present

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data['Date']=pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date            datetime64[ns]
# dtype: object

# %%
data['Date'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date, dtype: int64

# %%
data['Date'].dt.year.value_counts().plot(kind='bar')
plt.title('TV show and Movies added')
plt.xlabel('Years')
plt.ylabel('Total added Count')
plt.show()

# %% [markdown]
# By Graph we can say that 2019 there are highest movies and TV show are added

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='release_year', order=data['release_year'].value_counts().index[0:10], data=data)
plt.title('Content Releases in year')
plt.xlabel('Years')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# In 2018 netflix releases hoghest number of content both TV shows and Movies or 1017 and 2019 are same total number of content released.

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(x='type', data=data)
plt.title('Content on netflix')
plt.xlabel('Type')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# By graph we can say that there are highest number of movie are released on netflix and low TV Show are released.

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['year']=data['Date'].dt.year
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data[(data['type']== 'Movie')&(data['year']==2020)]
# Out:
#      show_id   type                                title  \
# 1470   s1471  Movie                     Alaska Is a Drag
# 1471   s1472  Movie                Best of Stand-Up 2020
# 1472   s1473  Movie                         Bobby Jasoos
# 1474   s1475  Movie                        Tarung Sarung
# 1475   s1476  Movie               Too Handsome to Handle
# ...      ...    ...                                  ...
# 8742   s8743  Movie                       Wild Wild West
# 8743   s8744  Movie                             Wildlife
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory
# 8764   s8765  Movie                           Wyatt Earp
# 8805   s8806  Movie                                 Zoom
#
#                        director  \
# 1470               Shaz Bennett
# 1471                        NaN
# 1472               Samar Shaikh
# 1474            Archie Hekagery
# 1475  Sabrina Rochelle Kalangie
# ...                         ...
# 8742           Barry Sonnenfeld
# ...

# %%
data['country'].value_counts().head(10)
# Out:
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: country, dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='country', order=data['country'].value_counts().index[0:10],data=data)
plt.title('Content produced by country')
plt.xlabel('Country')
plt.ylabel('Total')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# By the Graph we can identify that United State has produce the hights number of content combining both TV Show and Movies and India is second number in producing content.

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
movies_count=data[data['type']=='Movie']
movies_count
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
TV_Shows_coun=data[data['type']=='TV Show']

# %%
plt.figure(figsize=(6,3))
sns.countplot(y='country', order=data['country'].value_counts().index[0:10],data=TV_Shows_coun)
plt.title('TOP 10 TV Country Shows Produces')

plt.figure(figsize=(6,3))
sns.countplot(y='country', order=data['country'].value_counts().index[0:10],data=movies_count)
plt.title('TOP 10 Country Movies Produces')
# Out:
# Text(0.5, 1.0, 'TOP 10 Country Movies Produces')

# %% [markdown]
# In Graph United State Produces Highest Number of TV shows and Movied .
# India has produce second highest number of movies and United kingdom produces
# second Highest Number of TV Show.

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.rating.value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='rating', order=data.rating.value_counts().index[0:10],data=data)
plt.title('Rating of show in netflix')
# Out:
# Text(0.5, 1.0, 'Rating of show in netflix')

# %% [markdown]
# In TV-MA and TV-14 have the most of rating

# %%
data['listed_in'].value_counts()
# Out:
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: listed_in, Length: 514, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='listed_in',order=data['listed_in'].value_counts().index[0:10],data=data)
plt.title('Highest Number of Categories Watch')
# Out:
# Text(0.5, 1.0, 'Highest Number of Categories Watch')

# %% [markdown]
# People are more like to watch Dramas, International Movies and second is Documentary

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
data['month_added'] = pd.to_datetime(data['date_added']).dt.month_name()

# %%
month_Name = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
               'August', 'September', 'October', 'November', 'December']

# %%
monthly_counts = data['month_added'].value_counts().loc[month_Name]

# %%
plt.figure(figsize=(10,3))
sns.barplot(x=monthly_counts.index, y=monthly_counts.values)
plt.title('Content Added by Month')
plt.xlabel('Month')
plt.ylabel('total')
plt.show()

# %% [markdown]
# July emerged as the month when Netflix adds the most content, closely followed by December, indicating a strategic approach to content release.

# %%
data1=data[['type','release_year']]

# %%
data2=data1.groupby(['release_year', 'type']).size().reset_index(name='Total_count')

# %%
data2
# Out:
#      release_year     type  Total_count
# 0            1925  TV Show            1
# 1            1942    Movie            2
# 2            1943    Movie            3
# 3            1944    Movie            3
# 4            1945    Movie            3
# ..            ...      ...          ...
# 114          2019  TV Show          397
# 115          2020    Movie          517
# 116          2020  TV Show          436
# 117          2021    Movie          277
# 118          2021  TV Show          315
#
# [119 rows x 3 columns]

# %%
sns.lineplot(x='release_year', y='Total_count',data=data2, hue='type')
plt.title(' Movies Released per year Trand')
plt.xlabel('Year')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %% [markdown]
# Movies and TV Show are up trading after year 2000 and Netflix added higest numbar of movies after 2000

# %% [markdown]
# Conclusion
# With the help of this article, we have been able to learn about-
#
# 1.TV show and Movies added':By Graph we can say that 2019 there are highest movies and TV show are added by netflix as compaire to other years.
#
# 2.Quantity: Our analysis revealed that Netflix had added more movies than TV shows, aligning with the expectation that movies dominate their content library.
#
# 3.Content Releases in year:In 2018 netflix releases hoghest number of content both TV shows and Movies or 1017 and 2019 are same total number of content released.
#
# 4.Content on netflix:By graph we can say that there are highest number of movie are released on netflix and low TV Show are released.
#
# 5.Content produced by country:By the Graph we can identify that United State has produce the hights number of content combining both TV Show and Movies and India is second number in producing content.
#
# 6.TOP 10 Country content Produces:In Graph United State Produces Highest Number of TV shows and Movied . India has produce second highest number of movies and United kingdom produces second Highest Number of TV Show.
#
# 7.Rating of show in netflix:
#
# 8.Highest Number of Categories Watch:People are more like to watch Dramas, International Movies and the peoplealso like to watch Documentary as well.
#
# 9.Content Addition: July emerged as the month when Netflix adds the most content, closely followed by December, indicating a strategic approach to content release.
#
# 10.Movies Released per year Trand: Movies and TV Show are up trading after year 2000 and Netflix added higest numbar of movies after 2000
